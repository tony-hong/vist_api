# %%
import math
import os
import os.path as osp
import json
from datetime import datetime
from pprint import pprint
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 10)

# %% [markdown]
# ### VIST directory

# %%
annotations_dir = '/Users/tonyhong/ROOT/coli/SIND/data'
images_dir = ''

# %%
split = 'test'
# Load dii's split json
b = datetime.now()
path_to_dii_val = osp.join(annotations_dir, 'dii', split+'.description-in-isolation.json')
dii = json.load(open(path_to_dii_val))
print 'dii\'s [%s] loaded. It took %.2f seconds.' % (split, (datetime.now() - b).total_seconds())

# Load sis's split json
b = datetime.now()
path_to_sis_val = osp.join(annotations_dir, 'sis', split+'.story-in-sequence.json')
sis = json.load(open(path_to_sis_val))
print 'sis\'s [%s] loaded. It took %.2f seconds.' % (split, (datetime.now() - b).total_seconds())
# Out:
# dii's [test] loaded. It took 2.15 seconds.
# sis's [test] loaded. It took 0.79 seconds.

# %%
split = 'train'
# Load dii's split json
b = datetime.now()
path_to_dii_val = osp.join(annotations_dir, 'dii', split+'.description-in-isolation.json')
dii_train = json.load(open(path_to_dii_val))
print 'dii\'s [%s] loaded. It took %.2f seconds.' % (split, (datetime.now() - b).total_seconds())

# Load sis's split json
b = datetime.now()
path_to_sis_val = osp.join(annotations_dir, 'sis', split+'.story-in-sequence.json')
sis_train = json.load(open(path_to_sis_val))
print 'sis\'s [%s] loaded. It took %.2f seconds.' % (split, (datetime.now() - b).total_seconds())


split = 'val'
# Load dii's split json
b = datetime.now()
path_to_dii_val = osp.join(annotations_dir, 'dii', split+'.description-in-isolation.json')
dii_val = json.load(open(path_to_dii_val))
print 'dii\'s [%s] loaded. It took %.2f seconds.' % (split, (datetime.now() - b).total_seconds())

# Load sis's split json
b = datetime.now()
path_to_sis_val = osp.join(annotations_dir, 'sis', split+'.story-in-sequence.json')
sis_val = json.load(open(path_to_sis_val))
print 'sis\'s [%s] loaded. It took %.2f seconds.' % (split, (datetime.now() - b).total_seconds())
# Out:
# dii's [train] loaded. It took 8.95 seconds.
# sis's [train] loaded. It took 8.02 seconds.
# dii's [val] loaded. It took 0.45 seconds.
# sis's [val] loaded. It took 0.46 seconds.

# %%
# Let's check one ann
sis.keys()
# Out:
# [u'images', u'info', u'albums', u'type', u'annotations']

# %%
sis['annotations'][0]
# Out:
# [{u'album_id': u'44277',
#   u'original_text': u'The local parish holds a craft show each year.',
#   u'photo_flickr_id': u'1741642',
#   u'setting': u'first-2-pick-and-tell',
#   u'story_id': u'45530',
#   u'storylet_id': u'227650',
#   u'text': u'the local parish holds a craft show each year .',
#   u'tier': u'story-in-sequence',
#   u'worker_arranged_photo_order': 0,
#   u'worker_id': u'FJROI8NWDRIPAM1'}]

# %%
sis['images'][0]
# Out:
# {u'album_id': u'44277',
#  u'datetaken': u'2004-11-27 10:40:46',
#  u'id': u'1741642',
#  u'latitude': u'51.920449',
#  u'license': u'1',
#  u'longitude': u'-0.212688',
#  u'media': u'photo',
#  u'secret': u'81837e8e9e',
#  u'tags': u'stevenage fairies craftfair xmas 2004',
#  u'text': u'',
#  u'title': u'The venue.',
#  u'url_o': u'https://farm1.staticflickr.com/2/1741642_81837e8e9e_o.jpg'}

# %%
sis['albums'][3]
# Out:
# {u'date_create': u'1220783782',
#  u'date_update': u'1306981520',
#  u'description': u"Photo's from Father's Day 2008 at Tread, Wangaratta",
#  u'farm': u'4',
#  u'id': u'72157607155047588',
#  u'owner': u'50148267@N00',
#  u'photos': u'19',
#  u'primary': u'2835931462',
#  u'secret': u'fa6c97bfe2',
#  u'server': u'3010',
#  u'title': u"Father's Day 2008",
#  u'vist_label': u"father's_day"}

# %%
def show_album(alb_id):
    img_ids = alb_to_img_ids[alb_id]
    plt.figure()
    cols = 5
    rows = math.ceil(len(img_ids)/float(cols))
    for i, img_id in enumerate(img_ids):
        img = Images[img_id]
        img_file = osp.join(images_dir, split, img['id']+'.jpg')
#         img_content = imread(img_file)
#         img_content = imresize(img_content, (224, 224))
        ax = plt.subplot(rows, cols, i+1)
#         ax.imshow(img_content)
        ax.axis('off')
        ax.set_title(str(img_id)+'\n'+img['datetaken'][4:])
        print(img['url_o'])
    plt.show()

# %%
def show_story(story_id, show_image=True):
    result = []
    sent_ids = story_to_sent_ids[story_id]
    if show_image:
        plt.figure()
        for i, sent_id in enumerate(sent_ids):
            img_id = Sents[sent_id]['img_id']
            img = Images[img_id]
            img_file = osp.join(images_dir, split, str(img_id)+'.jpg')
#             img_content = imread(img_file)
#             img_content = imresize(img_content, (224, 224))
            ax = plt.subplot(1, len(sent_ids), i+1)
#             ax.imshow(img_content)
            ax.axis('off')
            ax.set_title(str(img_id)+'\n'+img['datetaken'][5:])
            print(img['url_o'])
        plt.show()
    for sent_id in sent_ids:
        sent = Sents[sent_id]
        img_id = sent['img_id']
        img = Images[img_id]
        line = '[%s], text[%s], image_url:\n %s' % (sent['order'], sent['original_text'], img['url_o'])
        result.append(line)
        print line
    return result

# %%
all_imgs = sis['images'] + sis_train['images'] + sis_val['images']
all_albums = sis['albums'] + sis_train['albums'] + sis_val['albums']

Images = {item['id']: item for item in sis_train['images']}
Albums = {item['id']: item for item in sis_train['albums']}
alb_to_img_ids = {}
for item in sis_train['images']:
    alb_id = item['album_id']
    img_id = item['id']
    alb_to_img_ids[alb_id] = alb_to_img_ids.get(alb_id, []) + [img_id]

# sort img_ids based on datetime
def getDateTime(img_id):
    x = Images[img_id]['datetaken']
    return datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
# for alb_id, img_ids in alb_to_img_ids.items():
#     img_ids.sort(key=getDateTime)

# %%
# make sents = [{}]
sents = []
for ann in sis_train['annotations']:
    sent = ann[0].copy()
    sent['id'] = sent.pop('storylet_id')
    sent['order'] = sent.pop('worker_arranged_photo_order')
    sent['img_id'] = sent.pop('photo_flickr_id')
    sents += [sent]
Sents = {sent['id']: sent for sent in sents}

# story_id -> sent_ids
story_to_sent_ids = {}
for sent_id, sent in Sents.items():
    story_id = sent['story_id']
    story_to_sent_ids[story_id] = story_to_sent_ids.get(story_id, []) + [sent_id]

def get_order(sent_id):
    return Sents[sent_id]['order']
for story_id, sent_ids in story_to_sent_ids.items():
    sent_ids.sort(key=get_order)
    
# alb_id -> story_ids
alb_to_story_ids = {}
for story_id, sent_ids in story_to_sent_ids.items():
    sent = Sents[sent_ids[0]]
    alb_id = sent['album_id']
    alb_to_story_ids[alb_id] = alb_to_story_ids.get(alb_id, []) + [story_id]

# %%
alb_id = '72157607155047588'
show_album(alb_id)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-286-fb123ca39a10> in <module>()
#       1 alb_id = '72157607155047588'
# ----> 2 show_album(alb_id)
#
# <ipython-input-112-8142dd2688c8> in show_album(alb_id)
#       5     rows = math.ceil(len(img_ids)/float(cols))
#       6     for i, img_id in enumerate(img_ids):
# ----> 7         img = Images[img_id]
#       8         img_file = osp.join(images_dir, split, img['id']+'.jpg')
#       9 #         img_content = imread(img_file)
#
# KeyError: u'2835915312'

# %%
story_ids = alb_to_story_ids[alb_id]
print 'This album has %s stories.' % len(story_ids)
show_story(story_ids[4], True)

# %%
# alb_ids = Albums.keys()
# alb_id = alb_ids[2]; print alb_id
# show_album(alb_id)

# %%
sis['type']

# %%
dii.keys()

# %%
pprint(dii['annotations'][0][0])
pprint(dii['annotations'][5][0])
# Out:
# {u'album_id': u'44277',
#  u'original_text': u'The sign is describing when the services will begin.',
#  u'photo_flickr_id': u'1741642',
#  u'photo_order_in_story': 0,
#  u'text': u'the sign is describing when the services will begin .',
#  u'tier': u'descriptions-in-isolation',
#  u'worker_id': u'X8GRFNA3PAZ87NZ'}
# {u'album_id': u'44277',
#  u'original_text': u'outer brick wall with red sign indicating name of church',
#  u'photo_flickr_id': u'1741642',
#  u'photo_order_in_story': 0,
#  u'text': u'outer brick wall with red sign indicating name of church',
#  u'tier': u'descriptions-in-isolation',
#  u'worker_id': u'Z8EVTCFDLQ7XIN7'}

# %%
sis['annotations'][0][0]
# Out:
# {u'album_id': u'44277',
#  u'original_text': u'The local parish holds a craft show each year.',
#  u'photo_flickr_id': u'1741642',
#  u'setting': u'first-2-pick-and-tell',
#  u'story_id': u'45530',
#  u'storylet_id': u'227650',
#  u'text': u'the local parish holds a craft show each year .',
#  u'tier': u'story-in-sequence',
#  u'worker_arranged_photo_order': 0,
#  u'worker_id': u'FJROI8NWDRIPAM1'}

# %%
sis['albums'][0]['id']
# Out:
# u'44277'

# %%
for i in range(len(sis['albums'])):
    if not sis['albums'][i]['id'] == dii['albums'][i]['id']:
        print 'inconsitancy found.'

# %%
sis['albums'][0]
# Out:
# {u'date_create': u'44277',
#  u'date_update': u'1396811566',
#  u'description': u"I left Stevenage over twenty years ago, having lived there between the ages of 7 and 20. Yesterday (on International Buy Nothing Day!) we returned for a 'Victorian Craft Fair' in the Church above the town Museum. Very strange...",
#  u'farm': u'1',
#  u'id': u'44277',
#  u'owner': u'37996585435@N01',
#  u'photos': u'23',
#  u'primary': u'1741611',
#  u'secret': u'3f374c96e5',
#  u'server': u'2',
#  u'title': u'A trip to Stevenage',
#  u'vist_label': u'fair'}

# %%
sis['images'][7]['id']
# Out:
# u'1741627'

# %%
sis['annotations'][14]
# Out:
# [{u'album_id': u'44277',
#   u'original_text': u'It makes them sad.',
#   u'photo_flickr_id': u'1741587',
#   u'setting': u'last-3-pick-old-and-tell',
#   u'story_id': u'45532',
#   u'storylet_id': u'227664',
#   u'text': u'it makes them sad .',
#   u'tier': u'story-in-sequence',
#   u'worker_arranged_photo_order': 4,
#   u'worker_id': u'351958JM3YVRMQL'}]

# %%
dii['annotations'][14]
# Out:
# [{u'album_id': u'44277',
#   u'original_text': u'A man wearing a top hat kneeling on the floor.',
#   u'photo_flickr_id': u'1741587',
#   u'photo_order_in_story': 4,
#   u'text': u'a man wearing a top hat kneeling on the floor .',
#   u'tier': u'descriptions-in-isolation',
#   u'worker_id': u'UNUY9179WKUI6Y9'}]

# %%
for i in range(len(sis['annotations'][:2])):
    sd = sis['annotations'][i][0]
    dd = dii['annotations'][i][0]
    if sd['album_id'] != dd['album_id'] or sd['photo_flickr_id'] != dd['photo_flickr_id']  \
        or sd['worker_arranged_photo_order'] != dd['photo_order_in_story']:
            print 'k'

# %%
import visual_genome.local as vg

# %%
VG_img_dats = vg.get_all_image_data('/Users/tonyhong/ROOT/coli/VisualGenome')

# %%
len(VG_img_dat)
# Out:
# 108077

# %%
flickr2VG = dict()
for i, VG_img in enumerate(VG_img_dats):
    flickr2VG[str(VG_img.flickr_id)] = i
#     if VG_img.flickr_id:
#     print VG_img.flickr_id
len(VG_flickr_ids)
# Out:
# 102502

# %%
VG_ids = set(flickr2VG.keys())
# flickr2VG[2835098587]

# %%
len_sis_test = len(sis['images'])
SIND_test_ids = {img['id'] for img in sis['images']}
SIND_train_ids = {img['id'] for img in sis_train['images']}
SIND_val_ids = {img['id'] for img in sis_val['images']}
print len(SIND_train_ids)
print len(SIND_val_ids)
# Out:
# 167528
# 21048

# %%
flickr2VG.keys()[0]
# Out:
# '8604230408'

# %%
joint_set = set()
joint_set.update(VG_ids & SIND_train_ids)
joint_set.update(VG_ids & SIND_test_ids)
joint_set.update(VG_ids & SIND_val_ids)
joint_list = list(joint_set)
len(joint_list)
# Out:
# 172

# %%
flickr2VG['497007959']
# Out:
# 2353431

# %%
import re

# print len(Images)
story_dict = dict()
for idx in joint_list:
    if Images.get(idx, -1) != -1:
#         print('image_id', idx)
        album_id = Images[idx]['album_id']
#         print('album_id', album_id)
        story_ids = alb_to_story_ids[album_id]
#         print('story_ids', story_ids)
        for story_id in story_ids:
            sent_ids = story_to_sent_ids[story_id]
            for sent_id in sent_ids:
                sent_img_id = Sents[sent_id]['img_id']
                if sent_img_id == idx:
                    sent = Sents[sent_id]['text']
                    if re.search(r'time|photo', sent):
                        continue
                    story_dict[story_id] = idx
#         print '\n'
        
len(story_dict)
# Out:
# 161

# %%
of = open('output.txt', 'w')
for it in story_dict.items():
    print it[1]
    show_story(it[0], False)
    print ''
    print ''
# Out:
# 21555842
# [0], text[While the cookout was being setup on the beach, a friendly game of frisbee was started.], image_url:
#  https://farm1.staticflickr.com/15/21555549_1cad7a3159_o.jpg
# [1], text[Georgio ready to return the frisbee.], image_url:
#  https://farm1.staticflickr.com/15/21555842_636bec55ce_o.jpg
# [2], text[Janet catching the frisbee one handed with skill.], image_url:
#  https://farm1.staticflickr.com/15/21556798_f59ff54534_o.jpg
# [3], text[An argument almost starts over the proper use of utensil as the food is served.], image_url:
#  https://farm1.staticflickr.com/17/21557484_73dc911c4c_o.jpg
# [4], text[A new bottle of wine was opened to ensure a steady flow of drinks.], image_url:
#  https://farm1.staticflickr.com/15/21557715_620a595de5_o.jpg
#
#
# 21555842
# [0], text[Extreme Frisbee is a popular sport.], image_url:
#  https://farm1.staticflickr.com/15/21555549_1cad7a3159_o.jpg
# [1], text[The players try to throw the frisbee towards goals up to 50 yards away.], image_url:
#  https://farm1.staticflickr.com/15/21555842_636bec55ce_o.jpg
# [2], text[This woman is preparting to throw her first shot.], image_url:
#  https://farm1.staticflickr.com/15/21556798_f59ff54534_o.jpg
# [3], text[After her throw she has to wait while others take their turns.], image_url:
#  https://farm1.staticflickr.com/17/21557484_73dc911c4c_o.jpg
# [4], text[The first person to hit the wine bottle with their frisbee will get one point.], image_url:
#  https://farm1.staticflickr.com/15/21557715_620a595de5_o.jpg
#
#
# 21555842
# [0], text[She had never seen men wearing kilts on the beach before. ], image_url:
#  https://farm1.staticflickr.com/15/21555549_1cad7a3159_o.jpg
# [1], text[This dude was really buff she thought. ], image_url:
#  https://farm1.staticflickr.com/15/21555842_636bec55ce_o.jpg
# [2], text[She caught the Frisbee when he threw it her way. ], image_url:
#  https://farm1.staticflickr.com/15/21556798_f59ff54534_o.jpg
# [3], text[She hoped to meet him and asked her friend to introduce her. ], image_url:
#  https://farm1.staticflickr.com/17/21557484_73dc911c4c_o.jpg
# [4], text[She saw him talking to an older man she assumed was his father. ], image_url:
#  https://farm1.staticflickr.com/15/21557715_620a595de5_o.jpg
#
#
# 4293438541
# [0], text[A couple decides they will go to a local market.], image_url:
#  https://farm5.staticflickr.com/4048/4294189082_afd9ce34a1_o.jpg
# [1], text[They see a young boy organizing bananas on the ground.], image_url:
#  https://farm3.staticflickr.com/2689/4293438541_4a55cf2b7c_o.jpg
# [2], text[They notice that everything sold here is handmade or grown. A woman works with a sewing machine.], image_url:
#  https://farm3.staticflickr.com/2794/4293517391_1ae684cce9_o.jpg
# [3], text[Another group has all of their products laying out across the ground.], image_url:
#  https://farm5.staticflickr.com/4013/4293505693_93c5a74b06_o.jpg
# [4], text[Finally they come across men that are wrapping toilet paper. This was an eye opening experience for the couple.], image_url:
#  https://farm5.staticflickr.com/4033/4294222884_112af022f0_o.jpg
#
#
# 2423336
# [0], text[Yesterday, while at my desk, I realized that I hadn't any cat food at home.], image_url:
#  https://farm1.staticflickr.com/1/2423336_97e124d45d_o.jpg
# [1], text[My poor cat Snuggles would be hungry when I got back.], image_url:
#  https://farm1.staticflickr.com/3/2423375_951496e07f_o.jpg
# [2], text[I went out into the night to the store.], image_url:
#  https://farm1.staticflickr.com/1/2423356_6dd1dc1cc9_o.jpg
# [3], text[I found Snuggles favorite cat food and brought it home.], image_url:
#  https://farm1.staticflickr.com/1/2423366_dc941cf90a_o.jpg
# [4], text[There, with Snuggles feed, I could relax and listen to my iPod.], image_url:
#  https://farm1.staticflickr.com/2/2423384_4273432d19_o.jpg
#
#
# 4293438541
# [0], text[The street was crowded with a busy market that sold a wide variety of goods.], image_url:
#  https://farm5.staticflickr.com/4048/4294189082_afd9ce34a1_o.jpg
# [1], text[This man is one of the few people who prepared the food to be sold in the market.], image_url:
#  https://farm3.staticflickr.com/2689/4293438541_4a55cf2b7c_o.jpg
# [2], text[This group of people were working hard on the clothes and fabrics to be sold at the market. ], image_url:
#  https://farm3.staticflickr.com/2794/4293517391_1ae684cce9_o.jpg
# [3], text[At the market some of the workers were starting to separate the goods they received. ], image_url:
#  https://farm5.staticflickr.com/4013/4293505693_93c5a74b06_o.jpg
# [4], text[Before the items even began to arrive at the market some of the workers inside the factory are hard at work getting materials ready. ], image_url:
#  https://farm5.staticflickr.com/4033/4294222884_112af022f0_o.jpg
#
#
# 5755702287
# [0], text[There is nothing better than a visit to the Air and Space Museum. Everywhere you look, there are historic aircraft.], image_url:
#  https://farm4.staticflickr.com/3518/5755702287_4d5e31ab38_o.jpg
# [1], text[One of my favorite exhibits is from the space program.], image_url:
#  https://farm4.staticflickr.com/3097/5755703811_552bca1860_o.jpg
# [2], text[It was a huge thrill to get to see the spacecraft up close. I'll never, ever forget it.], image_url:
#  https://farm3.staticflickr.com/2424/5756248600_61a89087d5_o.jpg
# [3], text[The whole history of flight can be read from the many exhibits.], image_url:
#  https://farm3.staticflickr.com/2551/5758069231_1c4b3a8638_o.jpg
# [4], text[This huge dark airplane takes you right up to the exciting present tense in air transport.], image_url:
#  https://farm3.staticflickr.com/2630/5758613454_ff060353d6_o.jpg
#
#
# 5755702287
# [0], text[The air and space museum was a sight to see, so many failed and lost designs.], image_url:
#  https://farm4.staticflickr.com/3518/5755702287_4d5e31ab38_o.jpg
# [1], text[Seeing the first space ship was amazing, I could hardly believe the human ingenuity. ], image_url:
#  https://farm4.staticflickr.com/3097/5755703811_552bca1860_o.jpg
# [2], text[NASA seemed so new, so novel back then, who knew it'd be on its way to obscurity now.], image_url:
#  https://farm3.staticflickr.com/2424/5756248600_61a89087d5_o.jpg
# [3], text[All the old Wright brother designs were fantastic, looking at them reminded me of when I was a child, and I wanted to go in the air.], image_url:
#  https://farm3.staticflickr.com/2551/5758069231_1c4b3a8638_o.jpg
# [4], text[Taking one last look at the spacecraft, I decided that I would get to space at some point in my life, come hell or high water.], image_url:
#  https://farm3.staticflickr.com/2630/5758613454_ff060353d6_o.jpg
#
#
# 5755702287
# [0], text[My family and I went to an airplane museum last week.], image_url:
#  https://farm4.staticflickr.com/3518/5755702287_4d5e31ab38_o.jpg
# [1], text[My favorite was this huge black and white airplane.], image_url:
#  https://farm4.staticflickr.com/3097/5755703811_552bca1860_o.jpg
# [2], text[It was an United States aircraft carrier with huge wings.], image_url:
#  https://farm3.staticflickr.com/2424/5756248600_61a89087d5_o.jpg
# [3], text[As we were nearing the exit of the museum I noticed this beautiful mural an artist created of a sky full of vintage airplanes.], image_url:
#  https://farm3.staticflickr.com/2551/5758069231_1c4b3a8638_o.jpg
# [4], text[Just when I thought it couldn't get any better, the exit of the museum was shaped like a luggage ramp on the bottom of airplanes.], image_url:
#  https://farm3.staticflickr.com/2630/5758613454_ff060353d6_o.jpg
#
#
# 5755702287
# [0], text[We went to a museum for space travel.], image_url:
#  https://farm4.staticflickr.com/3518/5755702287_4d5e31ab38_o.jpg
# [1], text[There where lots of different shttles.], image_url:
#  https://farm4.staticflickr.com/3097/5755703811_552bca1860_o.jpg
# [2], text[They where all displayed well.], image_url:
#  https://farm3.staticflickr.com/2424/5756248600_61a89087d5_o.jpg
# [3], text[There where lots of airplanes.], image_url:
#  https://farm3.staticflickr.com/2551/5758069231_1c4b3a8638_o.jpg
# [4], text[We really enjoyed our time there.], image_url:
#  https://farm3.staticflickr.com/2630/5758613454_ff060353d6_o.jpg
#
#
# 5755702287
# [0], text[Today was the big day that we went to the Air Museum.], image_url:
#  https://farm4.staticflickr.com/3518/5755702287_4d5e31ab38_o.jpg
# [1], text[I couldn't believe all the awesome planes], image_url:
#  https://farm4.staticflickr.com/3500/5756246978_15c0d3511f_o.jpg
# [2], text[and even one of the original space shuttles.], image_url:
#  https://farm4.staticflickr.com/3097/5755703811_552bca1860_o.jpg
# [3], text[I took enough pictures today to fill my vacation albums.], image_url:
#  https://farm3.staticflickr.com/2551/5758069231_1c4b3a8638_o.jpg
# [4], text[I will remember this day for the rest of my life with all the pictures that I took.], image_url:
#  https://farm3.staticflickr.com/2538/5760419111_075e72f61e_o.jpg
#
#
# 8657660045
# [0], text[A rally began for one of the political parties in London. ], image_url:
#  https://farm9.staticflickr.com/8111/8658767436_b409da9e9a_o.jpg
# [1], text[The guard marched in unison in front of a crowd. ], image_url:
#  https://farm9.staticflickr.com/8106/8658768128_f4d47952ed_o.jpg
# [2], text[The royal family showed up in a nice car. ], image_url:
#  https://farm9.staticflickr.com/8106/8658767044_41ebbcebc6_o.jpg
# [3], text[The horses looked strong and ready to take down assailants. ], image_url:
#  https://farm9.staticflickr.com/8102/8657660045_20fba68c2b_o.jpg
# [4], text[I left the rally because it got too boring to watch. ], image_url:
#  https://farm9.staticflickr.com/8118/8657659531_8494833f26_o.jpg
#
#
# 8675013003
# [0], text[The woman is excited that she just graduated.], image_url:
#  https://farm9.staticflickr.com/8519/8676119638_4054e48269_o.jpg
# [1], text[Her husband was there to support her.], image_url:
#  https://farm9.staticflickr.com/8115/8675013003_59efca210d_o.jpg
# [2], text[After the graduation, there is a party where she received a lot of gifts.], image_url:
#  https://farm9.staticflickr.com/8403/8676117866_b82ae19061_o.jpg
# [3], text[Someone gives her a purple necklace.], image_url:
#  https://farm9.staticflickr.com/8531/8676116908_3346c17aaa_o.jpg
# [4], text[Her sister is there to celebrate with her.], image_url:
#  https://farm9.staticflickr.com/8385/8675009249_f370439595_o.jpg
#
#
# 8657660045
# [0], text[Royal guards and military in their best dress, due to a sad day for the royal family.], image_url:
#  https://farm9.staticflickr.com/8106/8658768128_f4d47952ed_o.jpg
# [1], text[Everyone is watching from the buildings above as the royal family and friends arrive to the funeral. Guards await and stand guard out of respect.], image_url:
#  https://farm9.staticflickr.com/8106/8658767044_41ebbcebc6_o.jpg
# [2], text[Royal guards stand guard as royal family and guests make entry into the building.], image_url:
#  https://farm9.staticflickr.com/8100/8657660727_b75a664b76_o.jpg
# [3], text[Royal guards await the arrival of the royal family and friends.], image_url:
#  https://farm9.staticflickr.com/8102/8657660045_20fba68c2b_o.jpg
# [4], text[Military salute and guards stand at attention to pay respects of royal's body arriving at funeral.], image_url:
#  https://farm9.staticflickr.com/8118/8657659531_8494833f26_o.jpg
#
#
# 8657660045
# [0], text[Members of the Royal Family are traveling down the avenue.], image_url:
#  https://farm9.staticflickr.com/8111/8658767436_b409da9e9a_o.jpg
# [1], text[An honor guard precedes the Royal Family.], image_url:
#  https://farm9.staticflickr.com/8106/8658768128_f4d47952ed_o.jpg
# [2], text[The Royal Family's vehicle passes as the guards salute.], image_url:
#  https://farm9.staticflickr.com/8106/8658767044_41ebbcebc6_o.jpg
# [3], text[Some guards are mounted cavalry and follow the Royal Family vehicle. ], image_url:
#  https://farm9.staticflickr.com/8102/8657660045_20fba68c2b_o.jpg
# [4], text[The guards hold their salute as the Royal Family vehicle exits.], image_url:
#  https://farm9.staticflickr.com/8118/8657659531_8494833f26_o.jpg
#
#
# 8657660045
# [0], text[The elite gathered to watch the soldiers march.], image_url:
#  https://farm9.staticflickr.com/8111/8658767436_b409da9e9a_o.jpg
# [1], text[The soldiers looked completely disciplined as they waited for commands.], image_url:
#  https://farm9.staticflickr.com/8106/8658768128_f4d47952ed_o.jpg
# [2], text[The soldiers stood like statues as the cars passed.], image_url:
#  https://farm9.staticflickr.com/8106/8658767044_41ebbcebc6_o.jpg
# [3], text[There were some soldiers on horseback. ], image_url:
#  https://farm9.staticflickr.com/8102/8657660045_20fba68c2b_o.jpg
# [4], text[All the soldiers saluted as the royal family passed. ], image_url:
#  https://farm9.staticflickr.com/8118/8657659531_8494833f26_o.jpg
#
#
# 8657660045
# [0], text[Watching Princess Fergesson leave her home.], image_url:
#  https://farm9.staticflickr.com/8111/8658767436_b409da9e9a_o.jpg
# [1], text[Here are the guards, they have a tough job.], image_url:
#  https://farm9.staticflickr.com/8106/8658768128_f4d47952ed_o.jpg
# [2], text[Soluting the queen.], image_url:
#  https://farm9.staticflickr.com/8106/8658767044_41ebbcebc6_o.jpg
# [3], text[Watching the princess and queen leave.], image_url:
#  https://farm9.staticflickr.com/8102/8657660045_20fba68c2b_o.jpg
# [4], text[Bye to the princess and the queen.], image_url:
#  https://farm9.staticflickr.com/8118/8657659531_8494833f26_o.jpg
#
#
# 4293438541
# [0], text[James and I took a tour of the various forms of work available in the poor country. We started with the food market.], image_url:
#  https://farm5.staticflickr.com/4048/4294189082_afd9ce34a1_o.jpg
# [1], text[This man selling green bananas glared at us, resenting our fancy clothes.], image_url:
#  https://farm3.staticflickr.com/2689/4293438541_4a55cf2b7c_o.jpg
# [2], text[The woman working on the street hemming pants looked tired and discouraged.], image_url:
#  https://farm3.staticflickr.com/2794/4293517391_1ae684cce9_o.jpg
# [3], text[We went to the used clothing market, where mismatched shoes were sold cheaply.], image_url:
#  https://farm5.staticflickr.com/4013/4293505693_93c5a74b06_o.jpg
# [4], text[In a large warehouse, men packaged toilet paper. We ended the tour feeling very downbeat.], image_url:
#  https://farm5.staticflickr.com/4033/4294222884_112af022f0_o.jpg
#
#
# 9178291927
# [0], text[Lots of family members reunite for the family reunion each summer.], image_url:
#  https://farm6.staticflickr.com/5488/9180509342_7ec2a0c649_o.jpg
# [1], text[They will often reserve a pavilion in the local park to hold their party.], image_url:
#  https://farm8.staticflickr.com/7435/9178293239_0965bd12db_o.jpg
# [2], text[There is always lots of delicious food and drink to enjoy as well.], image_url:
#  https://farm4.staticflickr.com/3730/9178291927_a573d4f6be_o.jpg
# [3], text[Family members are never too young to enjoy reuniting, playing and enjoying the day.], image_url:
#  https://farm8.staticflickr.com/7437/9178290525_b3a44424e2_o.jpg
# [4], text[Come to speak of it, they are never too old, either!], image_url:
#  https://farm6.staticflickr.com/5462/9178286019_12e519e4a7_o.jpg
#
#
# 4293438541
# [0], text[Our vacation to the new country showed us so many wonders. ], image_url:
#  https://farm5.staticflickr.com/4048/4294189082_afd9ce34a1_o.jpg
# [1], text[All of the food was so neatly lined up.], image_url:
#  https://farm3.staticflickr.com/2689/4293438541_4a55cf2b7c_o.jpg
# [2], text[The women looked like they made the clothing.], image_url:
#  https://farm3.staticflickr.com/2794/4293517391_1ae684cce9_o.jpg
# [3], text[Children helped out in their local economies too.], image_url:
#  https://farm5.staticflickr.com/4013/4293505693_93c5a74b06_o.jpg
# [4], text[There were even small factories where people worked.], image_url:
#  https://farm5.staticflickr.com/4033/4294222884_112af022f0_o.jpg
#
#
# 394809929
# [0], text[We decided we would take a trip today.], image_url:
#  https://farm1.staticflickr.com/127/394785152_68f7d6bc2f_o.jpg
# [1], text[We went out to get a terrific view.], image_url:
#  https://farm1.staticflickr.com/133/394783421_6f6c9bd3b6_o.jpg
# [2], text[Then we drove back to get to the beach.], image_url:
#  https://farm1.staticflickr.com/166/394798079_68dc4aeaf0_o.jpg
# [3], text[It was swarming with birds,], image_url:
#  https://farm1.staticflickr.com/126/394798850_767abda718_o.jpg
# [4], text[but that didn't stop us from having fun!], image_url:
#  https://farm1.staticflickr.com/69/394809929_ab97724e1f_o.jpg
#
#
# 4644515065
# [0], text[THe girls were changing.], image_url:
#  https://farm5.staticflickr.com/4055/4644514845_5cb913cd1e_o.jpg
# [1], text[The elephants took the people away from them.], image_url:
#  https://farm4.staticflickr.com/3083/4644515065_9d41dc5d10_o.jpg
# [2], text[They didn't want to know what was in the pies.], image_url:
#  https://farm4.staticflickr.com/3334/4644515419_0bb7ba79a8_o.jpg
# [3], text[The deities smiled knowingly.], image_url:
#  https://farm4.staticflickr.com/3416/4645131666_4ecbf04a0a_o.jpg
# [4], text[The music began and everyone was confused.], image_url:
#  https://farm5.staticflickr.com/4035/4645133162_1d03813800_o.jpg
#
#
# 4644515065
# [0], text[we took an elephant ride to a festival ], image_url:
#  https://farm4.staticflickr.com/3083/4644515065_9d41dc5d10_o.jpg
# [1], text[in Indonesia festivals bring hope], image_url:
#  https://farm4.staticflickr.com/3405/4644515183_3c851ae046_o.jpg
# [2], text[elders watch as their children enjoy the party], image_url:
#  https://farm4.staticflickr.com/3365/4645131052_6b2e025481_o.jpg
# [3], text[the food is incredible], image_url:
#  https://farm4.staticflickr.com/3334/4644515419_0bb7ba79a8_o.jpg
# [4], text[and they pray to Buddah], image_url:
#  https://farm4.staticflickr.com/3416/4645131666_4ecbf04a0a_o.jpg
#
#
# 496978754
# [0], text[Leonard wanted to travel the world and take photographs of animals. He took a photo of a herd of American Bison.], image_url:
#  https://farm1.staticflickr.com/193/496978418_f673b1b2f4_o.jpg
# [1], text[Leonard also wanted to capture the animals personality. Look how sweet this deer is. ], image_url:
#  https://farm1.staticflickr.com/230/497007541_974017eaf9_o.jpg
# [2], text[The zebra has a regal look.], image_url:
#  https://farm1.staticflickr.com/199/496978754_27d20855e4_o.jpg
# [3], text[Leonard was thrilled to get this shot of a giraffe. ], image_url:
#  https://farm1.staticflickr.com/213/497007959_9c5a8227d6_o.jpg
# [4], text[Leonard was sure that camels have the silliest of personality's.], image_url:
#  https://farm1.staticflickr.com/194/497008265_5207c110fe_o.jpg
#
#
# 496978754
# [0], text[The mammoth traveled in packs. ], image_url:
#  https://farm1.staticflickr.com/193/496978418_f673b1b2f4_o.jpg
# [1], text[The deer was curious about its surrounding. ], image_url:
#  https://farm1.staticflickr.com/230/497007541_974017eaf9_o.jpg
# [2], text[Check out the dizzying stripes on the zebra. ], image_url:
#  https://farm1.staticflickr.com/199/496978754_27d20855e4_o.jpg
# [3], text[The giraffe cooled off in the cool grass. ], image_url:
#  https://farm1.staticflickr.com/213/497007959_9c5a8227d6_o.jpg
# [4], text[The camel showed off its dental work. ], image_url:
#  https://farm1.staticflickr.com/194/497008265_5207c110fe_o.jpg
#
#
# 4644515065
# [0], text[We had great vacation. We traveled to some amazing places. One of my favorite memories was traveling across a river while riding an elephant.], image_url:
#  https://farm4.staticflickr.com/3083/4644515065_9d41dc5d10_o.jpg
# [1], text[We saw many churches and temples and shrines. It was fun meeting all of the monks.], image_url:
#  https://farm4.staticflickr.com/3405/4644515183_3c851ae046_o.jpg
# [2], text[We met some amazing people.], image_url:
#  https://farm4.staticflickr.com/3365/4645131052_6b2e025481_o.jpg
# [3], text[The food we had was excellent. Better than anything I have ever eaten in my life.], image_url:
#  https://farm4.staticflickr.com/3334/4644515419_0bb7ba79a8_o.jpg
# [4], text[The art was great as well. The statues were great. This was a trip I will never forget.], image_url:
#  https://farm4.staticflickr.com/3416/4645131666_4ecbf04a0a_o.jpg
#
#
# 4644515065
# [0], text[A traditional routine performed daily.], image_url:
#  https://farm5.staticflickr.com/4055/4644514845_5cb913cd1e_o.jpg
# [1], text[Safely crossing the muddy river by elephants.], image_url:
#  https://farm4.staticflickr.com/3083/4644515065_9d41dc5d10_o.jpg
# [2], text[Traditional feast of local cuisine.], image_url:
#  https://farm4.staticflickr.com/3334/4644515419_0bb7ba79a8_o.jpg
# [3], text[Beautiful art displayed in various serene locations.], image_url:
#  https://farm4.staticflickr.com/3416/4645131666_4ecbf04a0a_o.jpg
# [4], text[Celebrating the feast we all shared earlier with music and dancing.], image_url:
#  https://farm5.staticflickr.com/4035/4645133162_1d03813800_o.jpg
#
#
# 5747366062
# [0], text[I and m friends like to volteer at the ready races], image_url:
#  https://farm3.staticflickr.com/2227/5746816873_7651cc82e7_o.jpg
# [1], text[we have different games set up], image_url:
#  https://farm3.staticflickr.com/2760/5747366062_41cd115be7_o.jpg
# [2], text[we also make sure that everyone have water], image_url:
#  https://farm3.staticflickr.com/2385/5746817029_965a33837e_o.jpg
# [3], text[even the animals come out], image_url:
#  https://farm4.staticflickr.com/3165/5769360853_3bf82ab58d_o.jpg
# [4], text[everyone have fun.], image_url:
#  https://farm3.staticflickr.com/2250/5769901152_e1c9556ab9_o.jpg
#
#
# 2423336
# [0], text[This is my home office where I spend most of my day.], image_url:
#  https://farm1.staticflickr.com/1/2423336_97e124d45d_o.jpg
# [1], text[My coworker never gossips or complains but does need to be fed.], image_url:
#  https://farm1.staticflickr.com/3/2423375_951496e07f_o.jpg
# [2], text[In search of cat food, I entered the address in GPS of the new pet store.], image_url:
#  https://farm1.staticflickr.com/1/2423356_6dd1dc1cc9_o.jpg
# [3], text[Grand opening prices were very much appreciated. ], image_url:
#  https://farm1.staticflickr.com/1/2423366_dc941cf90a_o.jpg
# [4], text[When I returned home I needed the right music before diving back into work.], image_url:
#  https://farm1.staticflickr.com/2/2423384_4273432d19_o.jpg
#
#
# 239658430
# [0], text[It was hot that day at the zoo and the even the bears tried to stay cool by swimming in their pond. ], image_url:
#  https://farm1.staticflickr.com/80/239643964_2e8e6bf298_o.jpg
# [1], text[The penguin looked like a frazzled rock star. ], image_url:
#  https://farm1.staticflickr.com/92/239652702_023704baa3_o.jpg
# [2], text[The giraffes couldn't find shade. ], image_url:
#  https://farm1.staticflickr.com/81/239658430_b1677705d3_o.jpg
# [3], text[The flamingo stayed in the pond. ], image_url:
#  https://farm1.staticflickr.com/82/241920008_11aa0a1896_o.jpg
# [4], text[The elephants tossed dust on their bodies. ], image_url:
#  https://farm1.staticflickr.com/85/241922947_f33a1b6021_o.jpg
#
#
# 4487608653
# [0], text[I got on a clock kick today. ], image_url:
#  https://farm5.staticflickr.com/4036/4487603015_4273df9244_o.jpg
# [1], text[I went around town and found clocks that were on buildings or freestanding.], image_url:
#  https://farm5.staticflickr.com/4017/4488253012_a7992452dd_o.jpg
# [2], text[I didn't realize there were so many.], image_url:
#  https://farm3.staticflickr.com/2680/4487605281_b58644d40d_o.jpg
# [3], text[I wonder if people just walk past and not notice them anymore.], image_url:
#  https://farm5.staticflickr.com/4006/4488529730_81a44fe5a9_o.jpg
# [4], text[I love the old fashioned look of them.], image_url:
#  https://farm5.staticflickr.com/4019/4487608653_b2d14bfcb1_o.jpg
#
#
# 4487608653
# [0], text[My friends and I were on a race to find all the clocks outside in town and here was the first in this park.], image_url:
#  https://farm5.staticflickr.com/4036/4487603015_4273df9244_o.jpg
# [1], text[I knew there was one on the side of this building so I went there next.], image_url:
#  https://farm5.staticflickr.com/4017/4488253012_a7992452dd_o.jpg
# [2], text[The clock on the side of the cafe would be my next visit.], image_url:
#  https://farm3.staticflickr.com/2680/4487605281_b58644d40d_o.jpg
# [3], text[I almost missed this one outside Fox Jewelers.], image_url:
#  https://farm5.staticflickr.com/4006/4488529730_81a44fe5a9_o.jpg
# [4], text[My final one was on this corner giving me the victory ! ], image_url:
#  https://farm5.staticflickr.com/4019/4487608653_b2d14bfcb1_o.jpg
#
#
# 2110453746
# [0], text[The elephants are doing a show at the zoo today. They can even take people on them.], image_url:
#  https://farm3.staticflickr.com/2171/2109676223_53aff3c999_o.jpg
# [1], text[The elephants are smart and can bow down and get on one knee.], image_url:
#  https://farm3.staticflickr.com/2203/2110453746_8d81db1847_o.jpg
# [2], text[A man rides the elephant and plays a game with a soccer ball.], image_url:
#  https://farm3.staticflickr.com/2321/2110454638_4550d2be60_o.jpg
# [3], text[The elephants can paint and put on a show for the people.], image_url:
#  https://farm3.staticflickr.com/2358/2109678779_fd9d4a098b_o.jpg
# [4], text[The girl pets the elephants snout after the event and gives it some peanuts.], image_url:
#  https://farm3.staticflickr.com/2251/2110448350_fd131f33ee_o.jpg
#
#
# 2110453746
# [0], text[The trainers paraded the elephants around for the crowd.], image_url:
#  https://farm3.staticflickr.com/2171/2109676223_53aff3c999_o.jpg
# [1], text[This big fellow was showing us how he could gently take his trainers cap off.], image_url:
#  https://farm3.staticflickr.com/2203/2110453746_8d81db1847_o.jpg
# [2], text[This elephant knows how to play soccer.], image_url:
#  https://farm3.staticflickr.com/2321/2110454638_4550d2be60_o.jpg
# [3], text[Wow, an elephant that can paint, amazing.], image_url:
#  https://farm3.staticflickr.com/2358/2109678779_fd9d4a098b_o.jpg
# [4], text[This baby elephant enjoys being fed by the tourists.], image_url:
#  https://farm3.staticflickr.com/2251/2110448350_fd131f33ee_o.jpg
#
#
# 2110453746
# [0], text[When we arrived at the camp, we noticed the elephant show was about to start. ], image_url:
#  https://farm3.staticflickr.com/2171/2109676223_53aff3c999_o.jpg
# [1], text[first they showed us a trick with a man and the elephant. He did several poses for us. ], image_url:
#  https://farm3.staticflickr.com/2203/2110453746_8d81db1847_o.jpg
# [2], text[then they showed us how much the elephants love playing soccer. ], image_url:
#  https://farm3.staticflickr.com/2321/2110454638_4550d2be60_o.jpg
# [3], text[some of the elephants are artists. they painted pictures and sold them after the show. ], image_url:
#  https://farm3.staticflickr.com/2358/2109678779_fd9d4a098b_o.jpg
# [4], text[at the end of the show they allowed us to meet with the elephants. we enjoyed meeting the animals that put on such a great show. ], image_url:
#  https://farm3.staticflickr.com/2251/2110448350_fd131f33ee_o.jpg
#
#
# 4235133980
# [0], text[John finally got his big promotion. We took it to celebrate.], image_url:
#  https://farm5.staticflickr.com/4025/4235133980_5fd3b7881e_o.jpg
# [1], text[Jimmy couldn't wait for grace, and started eating.], image_url:
#  https://farm5.staticflickr.com/4012/4235133674_9b63fedc8d_o.jpg
# [2], text[The waiter brought refills for everyone.], image_url:
#  https://farm5.staticflickr.com/4003/4234359217_8ddbe2e657_o.jpg
# [3], text[John's boss stopped by to join us. Him and John are real close.], image_url:
#  https://farm3.staticflickr.com/2573/4234359413_b509391787_o.jpg
# [4], text[Everyone was stuffed. We Stuck around for drinks.], image_url:
#  https://farm3.staticflickr.com/2690/4235134044_5bd7dbfe26_o.jpg
#
#
# 4235133804
# [0], text[We had a huge get together at the new Italian restaurant down the street.], image_url:
#  https://farm3.staticflickr.com/2690/4235134044_5bd7dbfe26_o.jpg
# [1], text[Everyone wanted to try the pizza.], image_url:
#  https://farm5.staticflickr.com/4012/4235133674_9b63fedc8d_o.jpg
# [2], text[We spent the evening sitting around the table talking.], image_url:
#  https://farm3.staticflickr.com/2719/4235133804_26bde68609_o.jpg
# [3], text[People were devouring the pizza and having a great time.], image_url:
#  https://farm5.staticflickr.com/4021/4234359597_a51753c485_o.jpg
# [4], text[Everyone agreed that the new Italian restaurant had the best pizza in the area. A good time was had by all.], image_url:
#  https://farm5.staticflickr.com/4025/4235133980_5fd3b7881e_o.jpg
#
#
# 4443792217
# [0], text[The new house is awesome.], image_url:
#  https://farm3.staticflickr.com/2683/4443792217_f58d49c2d9_o.jpg
# [1], text[Lots of room everywhere.], image_url:
#  https://farm3.staticflickr.com/2720/4443830095_4bb8238ae2_o.jpg
# [2], text[The kitchen is huge.], image_url:
#  https://farm5.staticflickr.com/4015/4443830121_e7e8571d92_o.jpg
# [3], text[As is the hallway next to it.], image_url:
#  https://farm3.staticflickr.com/2716/4443792213_d1e37c0324_o.jpg
# [4], text[The bedroom however is a bit too small.], image_url:
#  https://farm5.staticflickr.com/4056/4444549500_5867505171_o.jpg
#
#
# 4443792217
# [0], text[The living room in the house we rented.], image_url:
#  https://farm3.staticflickr.com/2683/4443792217_f58d49c2d9_o.jpg
# [1], text[I had a few plants there in the window.], image_url:
#  https://farm3.staticflickr.com/2720/4443830095_4bb8238ae2_o.jpg
# [2], text[The kitchen was beautiful.], image_url:
#  https://farm5.staticflickr.com/4015/4443830121_e7e8571d92_o.jpg
# [3], text[Looking towards the living room from the kitchen.], image_url:
#  https://farm3.staticflickr.com/2716/4443792213_d1e37c0324_o.jpg
# [4], text[The master bedroom looks inviting!], image_url:
#  https://farm5.staticflickr.com/4056/4444549500_5867505171_o.jpg
#
#
# 4443792217
# [0], text[The decor was classic and classy.], image_url:
#  https://farm3.staticflickr.com/2683/4443792217_f58d49c2d9_o.jpg
# [1], text[A lot of plants livened up the place.], image_url:
#  https://farm3.staticflickr.com/2720/4443830095_4bb8238ae2_o.jpg
# [2], text[The kitchen was small but well done.], image_url:
#  https://farm5.staticflickr.com/4015/4443830121_e7e8571d92_o.jpg
# [3], text[Overall the house was very appealing.], image_url:
#  https://farm3.staticflickr.com/2716/4443792213_d1e37c0324_o.jpg
# [4], text[The bedroom was also quite minimalist.], image_url:
#  https://farm5.staticflickr.com/4056/4444549500_5867505171_o.jpg
#
#
# 4454714874
# [0], text[I found a house I may want to buy today. This is the living room.], image_url:
#  https://farm3.staticflickr.com/2730/4454714874_3b729ef4cc_o.jpg
# [1], text[I like the master bedroom. It has enough room without being too big.], image_url:
#  https://farm5.staticflickr.com/4051/4454703964_b05897dd5e_o.jpg
# [2], text[There's a second bedroom I can use for company.], image_url:
#  https://farm5.staticflickr.com/4012/4454705060_ca3fc4bf18_o.jpg
# [3], text[The kitchen is large with plenty of counter space.], image_url:
#  https://farm3.staticflickr.com/2689/4454708066_91a80ec103_o.jpg
# [4], text[The dining room has a nice view. I really think I might buy this house.], image_url:
#  https://farm5.staticflickr.com/4058/4454712074_7fae4b3b86_o.jpg
#
#
# 4454714874
# [0], text[The living room was open and spacey.], image_url:
#  https://farm3.staticflickr.com/2730/4454714874_3b729ef4cc_o.jpg
# [1], text[I told my mom I would take the smallest bedroom.], image_url:
#  https://farm5.staticflickr.com/4051/4454703964_b05897dd5e_o.jpg
# [2], text[She got the master bedroom and some extra furniture.], image_url:
#  https://farm5.staticflickr.com/4012/4454705060_ca3fc4bf18_o.jpg
# [3], text[We met in the kitchen to discuss the dining room.], image_url:
#  https://farm3.staticflickr.com/2689/4454708066_91a80ec103_o.jpg
# [4], text[After that, we ate a small meal in our new house.], image_url:
#  https://farm5.staticflickr.com/4058/4454712074_7fae4b3b86_o.jpg
#
#
# 54069869
# [0], text[A man left his home town on his way to a business meeting.], image_url:
#  https://farm1.staticflickr.com/27/53856936_b6b371b4de_o.jpg
# [1], text[He flew past mountains....], image_url:
#  https://farm1.staticflickr.com/31/54069869_66a6b9859b_o.jpg
# [2], text[and over coastlines.], image_url:
#  https://farm1.staticflickr.com/29/54074882_ae80713567_o.jpg
# [3], text[He even saw the Hoover dam from his plane window. ], image_url:
#  https://farm1.staticflickr.com/26/53856812_af2bab67b2_o.jpg
# [4], text[When he arrived at his destination he was excited. He attended the meeting, learned new business strategies, and prepared to head back home to share the new information with his coworkers. ], image_url:
#  https://farm1.staticflickr.com/32/53856591_67d3409c5c_o.jpg
#
#
# 54069869
# [0], text[Mt. St Helen from the plane window.], image_url:
#  https://farm1.staticflickr.com/31/54069869_66a6b9859b_o.jpg
# [1], text[A closer view of the mountain top.], image_url:
#  https://farm1.staticflickr.com/31/53855900_c83753cf58_o.jpg
# [2], text[Mt. Raineer from the window of the plane.], image_url:
#  https://farm1.staticflickr.com/27/54070844_1441a046c6_o.jpg
# [3], text[A really high up view of a rainbow and the city.], image_url:
#  https://farm1.staticflickr.com/24/53856447_cf20b5b305_o.jpg
# [4], text[A close view of the city as we fly through it.], image_url:
#  https://farm1.staticflickr.com/32/53856591_67d3409c5c_o.jpg
#
#
# 54069869
# [0], text[The view from the plane was beautiful.], image_url:
#  https://farm1.staticflickr.com/31/54069869_66a6b9859b_o.jpg
# [1], text[I took a lot of pictures.], image_url:
#  https://farm1.staticflickr.com/31/53855900_c83753cf58_o.jpg
# [2], text[The mountains looked so small.], image_url:
#  https://farm1.staticflickr.com/27/54070844_1441a046c6_o.jpg
# [3], text[I also could see the beach.], image_url:
#  https://farm1.staticflickr.com/24/53856447_cf20b5b305_o.jpg
# [4], text[I could see my hotel!], image_url:
#  https://farm1.staticflickr.com/32/53856591_67d3409c5c_o.jpg
#
#
# 54069869
# [0], text[This was my first flight], image_url:
#  https://farm1.staticflickr.com/31/54069869_66a6b9859b_o.jpg
# [1], text[Used my camera to take some great pictures out the window.], image_url:
#  https://farm1.staticflickr.com/31/53855900_c83753cf58_o.jpg
# [2], text[Things look pretty amazing from so high up.], image_url:
#  https://farm1.staticflickr.com/27/54070844_1441a046c6_o.jpg
# [3], text[Finally the long flight comes to an end.], image_url:
#  https://farm1.staticflickr.com/24/53856447_cf20b5b305_o.jpg
# [4], text[Now that we're landed time for some beer!], image_url:
#  https://farm1.staticflickr.com/32/53856591_67d3409c5c_o.jpg
#
#
# 54069869
# [0], text[I took a helicopter ride on Friday and saw the entire city.], image_url:
#  https://farm1.staticflickr.com/27/53856936_b6b371b4de_o.jpg
# [1], text[I primarily wanted to see the snow-capped mountain tops.], image_url:
#  https://farm1.staticflickr.com/31/54069869_66a6b9859b_o.jpg
# [2], text[We got extremely fortunate and also got to see a rainbow from the sky.], image_url:
#  https://farm1.staticflickr.com/29/54074882_ae80713567_o.jpg
# [3], text[The highlight of the trip was seeing the Hoover Dam.], image_url:
#  https://farm1.staticflickr.com/26/53856812_af2bab67b2_o.jpg
# [4], text[We concluded our trip by landing back in the heart of the city.], image_url:
#  https://farm1.staticflickr.com/32/53856591_67d3409c5c_o.jpg
#
#
# 4294701202
# [0], text[My new house is everything I always wanted.], image_url:
#  https://farm3.staticflickr.com/2682/4294691800_ce7fd2cde3_o.jpg
# [1], text[Granted, I could use a little more room to store my books.], image_url:
#  https://farm3.staticflickr.com/2683/4293955635_9c1d849628_o.jpg
# [2], text[I could even use a little more more room for my clothes.], image_url:
#  https://farm5.staticflickr.com/4034/4294700030_388c51c3af_o.jpg
# [3], text[However, my bathroom is absolutely adorable.], image_url:
#  https://farm3.staticflickr.com/2557/4294699048_d6b6a2da5e_o.jpg
# [4], text[And I just love having a living room to call my own.], image_url:
#  https://farm3.staticflickr.com/2650/4294701202_a8be06a3d6_o.jpg
#
#
# 12264784
# [0], text[There was a festival in town this weekend.], image_url:
#  https://farm1.staticflickr.com/7/12265811_6079ce48c3_o.jpg
# [1], text[A bunch of people came out for the festivities.], image_url:
#  https://farm1.staticflickr.com/8/12267386_409eac1cc1_o.jpg
# [2], text[There was even a carnival.], image_url:
#  https://farm1.staticflickr.com/11/12264386_bde4e66d1f_o.jpg
# [3], text[The rides were a lot of fun.], image_url:
#  https://farm1.staticflickr.com/7/12263272_73afe63caf_o.jpg
# [4], text[Afterwards, everyone went home to drink and have fun.], image_url:
#  https://farm1.staticflickr.com/8/12264784_c93ea43a71_o.jpg
#
#
# 6086180880
# [0], text[We went on a city trip together and had a lot of fun.], image_url:
#  https://farm7.staticflickr.com/6077/6086179796_361ff3e2ab_o.jpg
# [1], text[The weather was not the best but we still made it.], image_url:
#  https://farm7.staticflickr.com/6085/6086180880_abc80efec3_o.jpg
# [2], text[We saw this lady with a dog with a crazy haircut.], image_url:
#  https://farm7.staticflickr.com/6066/6086184642_8eb91462da_o.jpg
# [3], text[The streets were pretty deserted and it was cold.], image_url:
#  https://farm7.staticflickr.com/6089/6085601871_739251a9b6_o.jpg
# [4], text[We decided to find a place to sit and warm up for awhile.], image_url:
#  https://farm7.staticflickr.com/6202/6086176550_84434822e5_o.jpg
#
#
# 4956733863
# [0], text[On the road trip,], image_url:
#  https://farm5.staticflickr.com/4125/4957304134_ca55983954_o.jpg
# [1], text[we stopped many places, ], image_url:
#  https://farm5.staticflickr.com/4078/4957307238_d42e4668f0_o.jpg
# [2], text[along the road.], image_url:
#  https://farm5.staticflickr.com/4152/4957324608_87d5944c10_o.jpg
# [3], text[Including this little area.], image_url:
#  https://farm5.staticflickr.com/4133/4956953469_7a98a03f33_o.jpg
# [4], text[We saw many people and animals.], image_url:
#  https://farm5.staticflickr.com/4125/4956733863_21c42c48c5_o.jpg
#
#
# 4956733863
# [0], text[Ken was on his way to the city to buy some sheep.], image_url:
#  https://farm5.staticflickr.com/4125/4957304134_ca55983954_o.jpg
# [1], text[He had to stop and rest for a while after being on the road for many miles.], image_url:
#  https://farm5.staticflickr.com/4078/4957307238_d42e4668f0_o.jpg
# [2], text[Back on the road again he was in route to get his sheep.], image_url:
#  https://farm5.staticflickr.com/4152/4957324608_87d5944c10_o.jpg
# [3], text[Looking to buy some sheep food first he stops and buys some.], image_url:
#  https://farm5.staticflickr.com/4133/4956953469_7a98a03f33_o.jpg
# [4], text[Finally arriving at the sheep market he is happy to buy some sheep.], image_url:
#  https://farm5.staticflickr.com/4125/4956733863_21c42c48c5_o.jpg
#
#
# 4623777092
# [0], text[We took Rocky and the boys out for a day at the beach.], image_url:
#  https://farm5.staticflickr.com/4009/4623776452_7b1d0ace91_o.jpg
# [1], text[Me and Rocky stopped for a quick photo.], image_url:
#  https://farm4.staticflickr.com/3334/4623176743_b45c60bb30_o.jpg
# [2], text[Maggie was undaunted by the steep slope.], image_url:
#  https://farm4.staticflickr.com/3417/4623783698_2b597632fd_o.jpg
# [3], text[They were happy to swim in the ocean.], image_url:
#  https://farm4.staticflickr.com/3336/4623777092_390cec927f_o.jpg
# [4], text[Maggie and Rocky played tug of war to dry off.], image_url:
#  https://farm5.staticflickr.com/4024/4623173591_628a25ab2f_o.jpg
#
#
# 6086180880
# [0], text[I had some trouble getting around town yesterday.], image_url:
#  https://farm7.staticflickr.com/6077/6086179796_361ff3e2ab_o.jpg
# [1], text[There were many stop signs.], image_url:
#  https://farm7.staticflickr.com/6085/6086180880_abc80efec3_o.jpg
# [2], text[I had to ask for directions.], image_url:
#  https://farm7.staticflickr.com/6066/6086184642_8eb91462da_o.jpg
# [3], text[I finally found the coffee shop.], image_url:
#  https://farm7.staticflickr.com/6089/6085601871_739251a9b6_o.jpg
# [4], text[Their coffee was very good.], image_url:
#  https://farm7.staticflickr.com/6202/6086176550_84434822e5_o.jpg
#
#
# 6086180880
# [0], text[We were excited to explore the city, and see everything it had to offer.], image_url:
#  https://farm7.staticflickr.com/6077/6086179796_361ff3e2ab_o.jpg
# [1], text[We drove aimlessly, taking random turns to see where we might end up.], image_url:
#  https://farm7.staticflickr.com/6085/6086180880_abc80efec3_o.jpg
# [2], text[Sam had a good look out the window, checking everything out.], image_url:
#  https://farm7.staticflickr.com/6066/6086184642_8eb91462da_o.jpg
# [3], text[Finally, we parked on a street we had never seen before.], image_url:
#  https://farm7.staticflickr.com/6089/6085601871_739251a9b6_o.jpg
# [4], text[It was time to take a break in our wandering for lunch.], image_url:
#  https://farm7.staticflickr.com/6202/6086176550_84434822e5_o.jpg
#
#
# 125933752
# [0], text[We cooked some chicken for dinner.], image_url:
#  https://farm1.staticflickr.com/50/125937190_adb77ca0e1_o.jpg
# [1], text[We even made salad with chicken.], image_url:
#  https://farm1.staticflickr.com/46/125934513_0e5a55f756_o.jpg
# [2], text[With a closer look, it looked more delicious.], image_url:
#  https://farm1.staticflickr.com/55/125933752_e6f45df494_o.jpg
# [3], text[We had enough food to cover today and tomorrow.], image_url:
#  https://farm1.staticflickr.com/46/125932288_5147f45f10_o.jpg
# [4], text[She was quick to put salad on our plates.], image_url:
#  https://farm1.staticflickr.com/39/125931162_54d9f8e7fc_o.jpg
#
#
# 4235133980
# [0], text[We had our fellowship meeting at a local Bar BQ place.], image_url:
#  https://farm3.staticflickr.com/2690/4235134044_5bd7dbfe26_o.jpg
# [1], text[We said a prayer before eating], image_url:
#  https://farm5.staticflickr.com/4012/4235133674_9b63fedc8d_o.jpg
# [2], text[Everyone really enjoyed the food.], image_url:
#  https://farm3.staticflickr.com/2719/4235133804_26bde68609_o.jpg
# [3], text[And of course with Bar BQ you have to have beer.], image_url:
#  https://farm5.staticflickr.com/4021/4234359597_a51753c485_o.jpg
# [4], text[The food, the beer and the fellowship were all superb.], image_url:
#  https://farm5.staticflickr.com/4025/4235133980_5fd3b7881e_o.jpg
#
#
# 125933752
# [0], text[This chicken is ready to be chopped up and added to a salad.], image_url:
#  https://farm1.staticflickr.com/50/125937190_adb77ca0e1_o.jpg
# [1], text[The perfect fixings for a great salad.], image_url:
#  https://farm1.staticflickr.com/46/125934513_0e5a55f756_o.jpg
# [2], text[Look at all that color!], image_url:
#  https://farm1.staticflickr.com/55/125933752_e6f45df494_o.jpg
# [3], text[Mix it all together and dinner is ready.], image_url:
#  https://farm1.staticflickr.com/46/125932288_5147f45f10_o.jpg
# [4], text[Now just have to serve it up and enjoy!], image_url:
#  https://farm1.staticflickr.com/39/125931162_54d9f8e7fc_o.jpg
#
#
# 4623777092
# [0], text[The dogs are running freely away from their owner.], image_url:
#  https://farm5.staticflickr.com/4009/4623776452_7b1d0ace91_o.jpg
# [1], text[One of the dogs decide to sit next to the owner.], image_url:
#  https://farm4.staticflickr.com/3334/4623176743_b45c60bb30_o.jpg
# [2], text[There is a dog standing on the side of a hill.], image_url:
#  https://farm4.staticflickr.com/3417/4623783698_2b597632fd_o.jpg
# [3], text[The dogs go to the water to play in the waves.], image_url:
#  https://farm4.staticflickr.com/3336/4623777092_390cec927f_o.jpg
# [4], text[The dogs are playing by the rocks.], image_url:
#  https://farm5.staticflickr.com/4024/4623173591_628a25ab2f_o.jpg
#
#
# 4235133980
# [0], text[I went with Bob to our company Christmas party.], image_url:
#  https://farm5.staticflickr.com/4025/4235133980_5fd3b7881e_o.jpg
# [1], text[There were many people there.], image_url:
#  https://farm5.staticflickr.com/4012/4235133674_9b63fedc8d_o.jpg
# [2], text[Look how long the tables were.], image_url:
#  https://farm5.staticflickr.com/4003/4234359217_8ddbe2e657_o.jpg
# [3], text[I sat at the end of the table.], image_url:
#  https://farm3.staticflickr.com/2573/4234359413_b509391787_o.jpg
# [4], text[I wanted to sit at this table in the back where it was quiet.], image_url:
#  https://farm3.staticflickr.com/2690/4235134044_5bd7dbfe26_o.jpg
#
#
# 5794131663
# [0], text[Making a hit.], image_url:
#  https://farm3.staticflickr.com/2001/5797838137_5a006f8f2f_o.jpg
# [1], text[About to serve the ball], image_url:
#  https://farm7.staticflickr.com/6189/6085472740_0f53370bc4_o.jpg
# [2], text[Curving the ball swiftly.], image_url:
#  https://farm6.staticflickr.com/5028/5790331774_130b808f6b_o.jpg
# [3], text[The power shop.], image_url:
#  https://farm3.staticflickr.com/2556/5796354884_16490d07fa_o.jpg
# [4], text[Waiting for the ball.], image_url:
#  https://farm6.staticflickr.com/5269/5794131663_df20cd02db_o.jpg
#
#
# 5794131663
# [0], text[The players were excited to play tennis.], image_url:
#  https://farm3.staticflickr.com/2001/5797838137_5a006f8f2f_o.jpg
# [1], text[They were professional at serving.], image_url:
#  https://farm7.staticflickr.com/6189/6085472740_0f53370bc4_o.jpg
# [2], text[Their swings were powerful.], image_url:
#  https://farm6.staticflickr.com/5028/5790331774_130b808f6b_o.jpg
# [3], text[These people were professional and knew their stance.], image_url:
#  https://farm3.staticflickr.com/2556/5796354884_16490d07fa_o.jpg
# [4], text[They were very competitive.], image_url:
#  https://farm6.staticflickr.com/5269/5794131663_df20cd02db_o.jpg
#
#
# 5794131663
# [0], text[The tennis match was intense.], image_url:
#  https://farm3.staticflickr.com/2001/5797838137_5a006f8f2f_o.jpg
# [1], text[Everyone tried their hardest to win.], image_url:
#  https://farm7.staticflickr.com/6189/6085472740_0f53370bc4_o.jpg
# [2], text[Both women and men were fighting for the trophy.], image_url:
#  https://farm6.staticflickr.com/5028/5790331774_130b808f6b_o.jpg
# [3], text[Everyone had a great time.], image_url:
#  https://farm3.staticflickr.com/2556/5796354884_16490d07fa_o.jpg
# [4], text[The winner played all day and was exhausted.], image_url:
#  https://farm6.staticflickr.com/5269/5794131663_df20cd02db_o.jpg
#
#
# 5790331774
# [0], text[Nadal seemed to be on his game today.], image_url:
#  https://farm6.staticflickr.com/5107/5792875589_87f24f44bd_o.jpg
# [1], text[This girl was pretty good as well.], image_url:
#  https://farm7.staticflickr.com/6189/6085472740_0f53370bc4_o.jpg
# [2], text[But the one in yellow ended winning.], image_url:
#  https://farm6.staticflickr.com/5028/5790331774_130b808f6b_o.jpg
# [3], text[She seemed to be happy.], image_url:
#  https://farm7.staticflickr.com/6077/6136499644_f7f55e5398_o.jpg
# [4], text[The boys did a victory lap for the girls.], image_url:
#  https://farm7.staticflickr.com/6007/6096964409_4e627558c7_o.jpg
#
#
# 4235133980
# [0], text[This dinner might be our last one together for a while, so we were all planning to celebrate it well. ], image_url:
#  https://farm3.staticflickr.com/2690/4235134044_5bd7dbfe26_o.jpg
# [1], text[We tried to be happy, but it was sad thinking about going different ways. ], image_url:
#  https://farm5.staticflickr.com/4012/4235133674_9b63fedc8d_o.jpg
# [2], text[In fact, a lot of the food was ignored. ], image_url:
#  https://farm3.staticflickr.com/2719/4235133804_26bde68609_o.jpg
# [3], text[Toward the end, people became happier. ], image_url:
#  https://farm5.staticflickr.com/4021/4234359597_a51753c485_o.jpg
# [4], text[It ended on a good note. ], image_url:
#  https://farm5.staticflickr.com/4025/4235133980_5fd3b7881e_o.jpg
#
#
# 5790331774
# [0], text[The tennis game started off we an ace serve.], image_url:
#  https://farm6.staticflickr.com/5107/5792875589_87f24f44bd_o.jpg
# [1], text[It was now Courtney's turn to serve.], image_url:
#  https://farm7.staticflickr.com/6189/6085472740_0f53370bc4_o.jpg
# [2], text[There was a good volley between the players.], image_url:
#  https://farm6.staticflickr.com/5028/5790331774_130b808f6b_o.jpg
# [3], text[Courtney won in the end.], image_url:
#  https://farm7.staticflickr.com/6077/6136499644_f7f55e5398_o.jpg
# [4], text[The ball boys seem to get younger and younger.], image_url:
#  https://farm7.staticflickr.com/6007/6096964409_4e627558c7_o.jpg
#
#
# 2110453746
# [0], text[I went on vacation to Bali and watched this talented artist creating umbrellas.], image_url:
#  https://farm3.staticflickr.com/2061/2110443502_7a47fb78b4_o.jpg
# [1], text[This is the woman's umbrella booth.], image_url:
#  https://farm3.staticflickr.com/2177/2109668181_9caa74277b_o.jpg
# [2], text[She has so many painted umbrellas for sale that it was hard to choose which one I wanted.], image_url:
#  https://farm3.staticflickr.com/2339/2110443702_50cdf857d0_o.jpg
# [3], text[After the outdoor market, we went to see an elephant show.], image_url:
#  https://farm3.staticflickr.com/2251/2110448350_fd131f33ee_o.jpg
# [4], text[The elephants are so tame and they can do all sorts of tricks.], image_url:
# ...
#  https://farm3.staticflickr.com/2723/4381463579_c68526ab73_o.jpg
# [2], text[It was amazing that the river was completely frozen over. ], image_url:
#  https://farm5.staticflickr.com/4071/4388417037_0cbe91fa0d_o.jpg
# [3], text[But the locals seemed to deal with the snow quite easily. ], image_url:
#  https://farm5.staticflickr.com/4024/4380913406_b470157d19_o.jpg
# [4], text[It really didn't even slow down the nightlife in the city at all. ], image_url:
#  https://farm3.staticflickr.com/2756/4379591463_45dd97ee94_o.jpg
#
#
# 4388417037
# [0], text[The world is covered with snow this morning.], image_url:
#  https://farm3.staticflickr.com/2783/4388415713_b0d43f158e_o.jpg
# [1], text[It looks so clean and fresh with all the snow.], image_url:
#  https://farm3.staticflickr.com/2723/4381463579_c68526ab73_o.jpg
# [2], text[Looks like the water is frozen under the bridge.], image_url:
#  https://farm5.staticflickr.com/4071/4388417037_0cbe91fa0d_o.jpg
# [3], text[Not many people out this cold, frigid morning.], image_url:
#  https://farm5.staticflickr.com/4024/4380913406_b470157d19_o.jpg
# [4], text[Ahh the cold nightlife, not many people out tonight,], image_url:
#  https://farm3.staticflickr.com/2756/4379591463_45dd97ee94_o.jpg
#
#
# 4388417037
# [0], text[There are lots of ways to get around besides driving.], image_url:
#  https://farm3.staticflickr.com/2783/4388415713_b0d43f158e_o.jpg
# [1], text[It is pretty slick on these ramps.], image_url:
#  https://farm3.staticflickr.com/2723/4381463579_c68526ab73_o.jpg
# [2], text[You can take a train.], image_url:
#  https://farm5.staticflickr.com/4071/4388417037_0cbe91fa0d_o.jpg
# [3], text[There are boats that will help you cross the river.], image_url:
#  https://farm5.staticflickr.com/4024/4380913406_b470157d19_o.jpg
# [4], text[Or you can just walk.], image_url:
#  https://farm3.staticflickr.com/2756/4379591463_45dd97ee94_o.jpg
#
#
# 6942011222
# [0], text[I day of fun up at the ski slope], image_url:
#  https://farm8.staticflickr.com/7036/7088077295_fcaf1bdd73_o.jpg
# [1], text[I dropped my glove when I was getting ready to go. ], image_url:
#  https://farm8.staticflickr.com/7194/6942007216_823a6bdb60_o.jpg
# [2], text[The lift was a little scary but had a great view. ], image_url:
#  https://farm6.staticflickr.com/5458/6942008352_1045ed94cd_o.jpg
# [3], text[At the top, I was ready to head down the hill.], image_url:
#  https://farm8.staticflickr.com/7261/6942011222_8f8bfe001d_o.jpg
# [4], text[A little too cold to set out for a suntan!], image_url:
#  https://farm8.staticflickr.com/7126/7088084775_43788b5bf4_o.jpg
#
#
# 497991041
# [0], text[Our small town neighborhood is very typical of rural America.], image_url:
#  https://farm1.staticflickr.com/199/497991041_1beb4c17ae_o.jpg
# [1], text[We live on a very quiet street with barely any crime to speak of.], image_url:
#  https://farm1.staticflickr.com/221/502266936_ce4ef7dd20_o.jpg
# [2], text[It's a slower paced way of life in this area of the country.], image_url:
#  https://farm1.staticflickr.com/222/489239462_6afbab9bea_o.jpg
# [3], text[We've had the same industries here for almost 100 years.], image_url:
#  https://farm1.staticflickr.com/218/491303147_d691037656_o.jpg
# [4], text[I do wish people would respect our environment however because the little is starting to become worse.], image_url:
#  https://farm1.staticflickr.com/211/500042932_1a22e8b6a6_o.jpg
#
#
# 6942011222
# [0], text[Its winter a time to go for winter activities.], image_url:
#  https://farm8.staticflickr.com/7036/7088077295_fcaf1bdd73_o.jpg
# [1], text[A piece of winter gloves was left in the ground.], image_url:
#  https://farm8.staticflickr.com/7194/6942007216_823a6bdb60_o.jpg
# [2], text[Some people tried the zipline.], image_url:
#  https://farm6.staticflickr.com/5458/6942008352_1045ed94cd_o.jpg
# [3], text[And this lady choose to ski.], image_url:
#  https://farm8.staticflickr.com/7261/6942011222_8f8bfe001d_o.jpg
# [4], text[Don't go beyond this point because this is the edge of the mountain.], image_url:
#  https://farm8.staticflickr.com/7126/7088084775_43788b5bf4_o.jpg
#
#
# 4254661432
# [0], text[There were hardly any cars on the road today so I decided to ride by bike throughout the city.], image_url:
#  https://farm3.staticflickr.com/2701/4254661432_5c2b7eeaf2_o.jpg
# [1], text[The entire neighborhood was empty.], image_url:
#  https://farm5.staticflickr.com/4040/4254662444_050bd986d6_o.jpg
# [2], text[I had a lot of fun riding around.], image_url:
#  https://farm5.staticflickr.com/4067/4255349103_f0c298d04a_o.jpg
# [3], text[I decided to ride into this tunnel.], image_url:
#  https://farm5.staticflickr.com/4015/4434842774_b471e1dda1_o.jpg
# [4], text[There were no cars in here either.], image_url:
#  https://farm5.staticflickr.com/4023/4434067087_58e943fd69_o.jpg
#
#
# 4254661432
# [0], text[We went for a bike ride the other day and made sure to stay in the bike lane.], image_url:
#  https://farm3.staticflickr.com/2701/4254661432_5c2b7eeaf2_o.jpg
# [1], text[We made sure to read the signs like this one telling us to yield.], image_url:
#  https://farm5.staticflickr.com/4040/4254662444_050bd986d6_o.jpg
# [2], text[We rode pretty fast and went under several bridges.], image_url:
#  https://farm5.staticflickr.com/4067/4255349103_f0c298d04a_o.jpg
# [3], text[We approached the tunnel and were not sure if we should enter.], image_url:
#  https://farm5.staticflickr.com/4015/4434842774_b471e1dda1_o.jpg
# [4], text[We decided that we would be alright and rode through the tunnel.], image_url:
#  https://farm5.staticflickr.com/4023/4434067087_58e943fd69_o.jpg
#
#
# 4254661432
# [0], text[I decided to go fo a bike ride], image_url:
#  https://farm3.staticflickr.com/2701/4254661432_5c2b7eeaf2_o.jpg
# [1], text[I was riding along this street, taking in the scenery], image_url:
#  https://farm5.staticflickr.com/4067/4255349103_f0c298d04a_o.jpg
# [2], text[Then I headed toward the building to check it out], image_url:
#  https://farm3.staticflickr.com/2682/4434838756_3d0f515231_o.jpg
# [3], text[Then I was on my way to the landmark], image_url:
#  https://farm5.staticflickr.com/4033/4434063201_d007d1fffb_o.jpg
# [4], text[I finally arrived at the landmark. What a sight!], image_url:
#  https://farm3.staticflickr.com/2792/4355730514_3de3bfa955_o.jpg
#
#
# 4254661432
# [0], text[The city was very bike friendly.], image_url:
#  https://farm3.staticflickr.com/2701/4254661432_5c2b7eeaf2_o.jpg
# [1], text[The man rode his bike around the city. The pathway went under a building.], image_url:
#  https://farm5.staticflickr.com/4067/4255349103_f0c298d04a_o.jpg
# [2], text[He road further along the path.], image_url:
#  https://farm3.staticflickr.com/2682/4434838756_3d0f515231_o.jpg
# [3], text[He came upon a bridge.], image_url:
#  https://farm5.staticflickr.com/4033/4434063201_d007d1fffb_o.jpg
# [4], text[On the other side he found a statue. ], image_url:
#  https://farm3.staticflickr.com/2792/4355730514_3de3bfa955_o.jpg
#
#
# 4254661432
# [0], text[The streets "Only Bike".], image_url:
#  https://farm3.staticflickr.com/2701/4254661432_5c2b7eeaf2_o.jpg
# [1], text[The street is empty.], image_url:
#  https://farm5.staticflickr.com/4040/4254662444_050bd986d6_o.jpg
# [2], text[A man is on his bike on the side of the road.], image_url:
#  https://farm5.staticflickr.com/4067/4255349103_f0c298d04a_o.jpg
# [3], text[The sun is shining outside today.], image_url:
#  https://farm5.staticflickr.com/4015/4434842774_b471e1dda1_o.jpg
# [4], text[This is a picture of a tunnel.], image_url:
#  https://farm5.staticflickr.com/4023/4434067087_58e943fd69_o.jpg
#
#
# 6942011222
# [0], text[Here is a picture of the slopes where we are spending a few days.], image_url:
#  https://farm8.staticflickr.com/7036/7088077295_fcaf1bdd73_o.jpg
# [1], text[Off course this is on of my gloves.], image_url:
#  https://farm8.staticflickr.com/7194/6942007216_823a6bdb60_o.jpg
# [2], text[Here is a scenic of the snow runs that go very far at least 2 miles.], image_url:
#  https://farm6.staticflickr.com/5458/6942008352_1045ed94cd_o.jpg
# [3], text[Here I am trying my hand at skiing. I no I will probably fall a lot.], image_url:
#  https://farm8.staticflickr.com/7261/6942011222_8f8bfe001d_o.jpg
# [4], text[They have chairs for people to sit on and take a break or enjoy the view.], image_url:
#  https://farm8.staticflickr.com/7126/7088084775_43788b5bf4_o.jpg
#
#
# 109542125
# [0], text[Leaves home and go to the woods], image_url:
#  https://farm1.staticflickr.com/19/109539948_937fad01ba_o.jpg
# [1], text[On there way to the woods], image_url:
#  https://farm1.staticflickr.com/51/109542125_9a8ff042ab_o.jpg
# [2], text[Arrive at the woods and look at the view], image_url:
#  https://farm1.staticflickr.com/45/109539953_0ffc51394e_o.jpg
# [3], text[Looking at the things close up], image_url:
#  https://farm1.staticflickr.com/53/109731928_256b673187_o.jpg
# [4], text[Looking at everything before leaving ], image_url:
#  https://farm1.staticflickr.com/42/109545784_6c67e37c8a_o.jpg
#
#
# 109542125
# [0], text[I bet this street is so gorgeous in the spring and summer.], image_url:
#  https://farm1.staticflickr.com/19/109539948_937fad01ba_o.jpg
# [1], text[So you're telling me I'm going the wrong way down a two-way street?], image_url:
#  https://farm1.staticflickr.com/51/109542125_9a8ff042ab_o.jpg
# [2], text[This tree is completely perpendicular to the the stream.], image_url:
#  https://farm1.staticflickr.com/45/109539953_0ffc51394e_o.jpg
# [3], text[Jen is watching the fish swim in there.], image_url:
#  https://farm1.staticflickr.com/53/109731928_256b673187_o.jpg
# [4], text[This place is so peaceful.], image_url:
#  https://farm1.staticflickr.com/42/109545784_6c67e37c8a_o.jpg
#
#
# 394809929
# [0], text[Bradley and his wife decided to take a day at the beach.], image_url:
#  https://farm1.staticflickr.com/127/394785152_68f7d6bc2f_o.jpg
# [1], text[They drove by beautifully rolling hills.], image_url:
#  https://farm1.staticflickr.com/133/394783421_6f6c9bd3b6_o.jpg
# [2], text[They finally made it after 2 hours of driving.], image_url:
#  https://farm1.staticflickr.com/166/394798079_68dc4aeaf0_o.jpg
# [3], text[They decided to feed the seagulls.], image_url:
#  https://farm1.staticflickr.com/126/394798850_767abda718_o.jpg
# [4], text[It was a beautiful day!], image_url:
#  https://farm1.staticflickr.com/69/394809929_ab97724e1f_o.jpg
#
#
# 6725164159
# [0], text[I went to hang out with my friend at his house today. He loves pottery.], image_url:
#  https://farm8.staticflickr.com/7167/6725162673_60e9d6a74d_o.jpg
# [1], text[He showed me how he makes all of his stuff.], image_url:
#  https://farm8.staticflickr.com/7018/6725164159_f3c9d201cd_o.jpg
# [2], text[He has a beautiful collection of vases.], image_url:
#  https://farm8.staticflickr.com/7159/6725165473_de41f2b737_o.jpg
# [3], text[Outside of his home he also has a bunch of animals like sheep.], image_url:
#  https://farm8.staticflickr.com/7029/6725166087_24c141c169_o.jpg
# [4], text[As well as camels.], image_url:
#  https://farm8.staticflickr.com/7162/6725167533_75a892260b_o.jpg
#
#
# 6725164159
# [0], text[I am a potter. I love to work with my hands and make things out of clay.], image_url:
#  https://farm8.staticflickr.com/7167/6725162673_60e9d6a74d_o.jpg
# [1], text[I choose a piece of clay and work carefully to make the object I want.], image_url:
#  https://farm8.staticflickr.com/7018/6725164159_f3c9d201cd_o.jpg
# [2], text[I love to see my work come alive before my eyes.], image_url:
#  https://farm8.staticflickr.com/7173/6725164761_f20ab093a8_o.jpg
# [3], text[Here are some of the vases that I completed.], image_url:
#  https://farm8.staticflickr.com/7159/6725165473_de41f2b737_o.jpg
# [4], text[I will get on my camel and bring my vases to the market to sell them.], image_url:
#  https://farm8.staticflickr.com/7009/6725168391_054a381980_o.jpg
#
#
# 6725164159
# [0], text[A beautiful trip with the kids to some of the more secluded areas in Egypt. Our guide introduced us to this pottery-worker.], image_url:
#  https://farm8.staticflickr.com/7167/6725162673_60e9d6a74d_o.jpg
# [1], text[We watched him work his magic for almost an hour! ], image_url:
#  https://farm8.staticflickr.com/7018/6725164159_f3c9d201cd_o.jpg
# [2], text[At the end, we went and bought almost every pot you see here! He was so excited!], image_url:
#  https://farm8.staticflickr.com/7159/6725165473_de41f2b737_o.jpg
# [3], text[The kids were more interested in the goats, though, and spent a lot of time with them after we left.], image_url:
#  https://farm8.staticflickr.com/7029/6725166087_24c141c169_o.jpg
# [4], text[We hitched our way on a camel and rode off, that day done. ], image_url:
#  https://farm8.staticflickr.com/7162/6725167533_75a892260b_o.jpg
#
#
# 173594375
# [0], text[Pictures of cows are taken while they walk around the farm.], image_url:
#  https://farm1.staticflickr.com/61/173594375_197d730ddd_o.jpg
# [1], text[A guy takes a picture by a stack of logs.], image_url:
#  https://farm1.staticflickr.com/52/173578918_5a0cfb6e5b_o.jpg
# [2], text[A girl puts her head in the soccer ball.], image_url:
#  https://farm1.staticflickr.com/59/173578916_12d78c15e2_o.jpg
# [3], text[Some people get inside of the boat to ride around for a bit.], image_url:
#  https://farm1.staticflickr.com/56/173588976_b5257f81c9_o.jpg
# [4], text[A fire is being made to keep warm where their at.], image_url:
#  https://farm1.staticflickr.com/44/173578920_584618130d_o.jpg
#
#
# 173594375
# [0], text[We weren't sure what we were getting into when the road was blocked with cattle.], image_url:
#  https://farm1.staticflickr.com/61/173594375_197d730ddd_o.jpg
# [1], text[The campsite was nice, with lots of amenities.], image_url:
#  https://farm1.staticflickr.com/52/173578918_5a0cfb6e5b_o.jpg
# [2], text[Some people started a game of volleyball.], image_url:
#  https://farm1.staticflickr.com/59/173578916_12d78c15e2_o.jpg
# [3], text[While others headed to the lake for some boating.], image_url:
#  https://farm1.staticflickr.com/56/173588976_b5257f81c9_o.jpg
# [4], text[We ended the day with a great bonfire.], image_url:
#  https://farm1.staticflickr.com/44/173578920_584618130d_o.jpg
#
#
# 173594375
# [0], text[The family was exploring a farm today.], image_url:
#  https://farm1.staticflickr.com/61/173594375_197d730ddd_o.jpg
# [1], text[There was lots of things going on.], image_url:
#  https://farm1.staticflickr.com/52/173578918_5a0cfb6e5b_o.jpg
# [2], text[Kelly wanted to play volleyball.], image_url:
#  https://farm1.staticflickr.com/59/173578916_12d78c15e2_o.jpg
# [3], text[John wanted to go in the canoe.], image_url:
#  https://farm1.staticflickr.com/56/173588976_b5257f81c9_o.jpg
# [4], text[At the end of the day they had a fire.], image_url:
#  https://farm1.staticflickr.com/44/173578920_584618130d_o.jpg
#
#
# 6725164159
# [0], text[I like to vacation in unusual places, liek this combined pottery/llama farm.], image_url:
#  https://farm8.staticflickr.com/7167/6725162673_60e9d6a74d_o.jpg
# [1], text[I took pottery lessons, and made some vases.], image_url:
#  https://farm8.staticflickr.com/7018/6725164159_f3c9d201cd_o.jpg
# [2], text[Once they were fired and dried, I painted them. I think they turned out pretty well!], image_url:
#  https://farm8.staticflickr.com/7159/6725165473_de41f2b737_o.jpg
# [3], text[The llamas were quite a sight to see. There were a lot of them.], image_url:
#  https://farm8.staticflickr.com/7029/6725166087_24c141c169_o.jpg
# [4], text[An added bonus was the camel kept on site. I've never been that close to a camel.], image_url:
#  https://farm8.staticflickr.com/7162/6725167533_75a892260b_o.jpg
#
#
# 6725164159
# [0], text[Ahmed began to sculpt his pots. ], image_url:
#  https://farm8.staticflickr.com/7167/6725162673_60e9d6a74d_o.jpg
# [1], text[He worked hard on them for many days. ], image_url:
#  https://farm8.staticflickr.com/7018/6725164159_f3c9d201cd_o.jpg
# [2], text[He created pots in many different shapes and sizes. ], image_url:
#  https://farm8.staticflickr.com/7173/6725164761_f20ab093a8_o.jpg
# [3], text[Finally, they were all dried and painted and ready to be sold at the market. ], image_url:
#  https://farm8.staticflickr.com/7159/6725165473_de41f2b737_o.jpg
# [4], text[Ahmed loaded the pots onto his camels and set off toward the market. ], image_url:
#  https://farm8.staticflickr.com/7009/6725168391_054a381980_o.jpg

# %%
VG_img_dat[flickr2VG['21555842']]
# Out:
# id: 2321518, coco_id: -1, flickr_id: 21555842, width: 500, url: https://cs.stanford.edu/people/rak248/VG_100K/2321518.jpg

# %%
graph = api.get_scene_graph_of_image(id=2321518)
graph.relationships
# Out:
# [4539201: person at park,
#  4539202: indentations IN sand,
#  4539203: indentation IN sand,
#  4539204: indentation IN sand,
#  4539205: indentation IN sand,
#  4539206: small indentions IN sand,
#  3753917: indentions IN sand,
#  4539207: indentions IN sand,
#  4539208: indentations IN sand,
#  3787315: sand IN indention,
#  4539209: indentions IN sand,
#  4539210: indentations IN sand,
#  3787318: indentions IN sand,
#  3754007: frisbee IN hands,
#  4539211: shadow OF man,
#  4539212: man holding frisbee,
#  4539213: blue bottom worn by man,
#  3754063: tattoo ON shoulder,
#  3754064: shoulder OF man,
#  4539214: sunglasses ON face,
#  4539215: necklace ON man,
#  4539216: watch ON arm,
#  4539217: person with shirt,
#  4539218: frisbee IN hand,
#  4539219: tattoo ON shoulder,
#  3787352: man WEARING watch,
#  3787354: picnic table behind man,
#  3787353: man holding frisbee,
#  4539220: necklace around man,
#  4539221: man holding frisbee,
#  3787361: man holding frisbee,
#  3787364: man WEARING sunglasses,
#  4539222: man standing in sand,
#  3787370: tattoo on arm of man,
#  4539223: man sitting at a table,
#  3787373: man Wearing a shirt,
#  4539224: man WEARING hat,
#  3787377: tracks ON sand,
#  3787380: person WEARING necklace]
